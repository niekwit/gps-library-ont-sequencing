# %%
# Moving barcode sequences to ORF read headers

To couple the ORF sequences with their corresponding barcode sequences, we will move the barcode sequences to the ORF read headers. 

This way, we can easily link the ORF sequences with their corresponding barcodes for downstream analysis.
